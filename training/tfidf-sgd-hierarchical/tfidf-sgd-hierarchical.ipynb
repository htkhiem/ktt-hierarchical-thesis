# %% [markdown]
# # References
# https://pypi.org/project/sklearn-hierarchical-classification/
# https://github.com/globality-corp/sklearn-hierarchical-classification/blob/develop/examples/classify_digits.py
#
#
# # Connect to Shared Drive

# %%
from google.colab import drive
drive.mount('/content/drive/') 

# Note that we don't use '!' here, so we can use IPython's builtin cd utility. Else we'd be running cd in a subshell, which is pointless.
# %cd "/content/drive/Shareddrives/Thesis/Data"

# Check if we can see our data
# !ls
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/Shareddrives/Thesis/Data
# a.dot
# All_Amazon_100k_root_svm_title_desc.pkl
# All_Amazon_Meta_chunks
# All_Amazon_r375k_hierarchical_title_desc.pkl
# All_Amazon_r750k_desc_cleaned.feather
# All_Amazon_r750k_empty_dropped_cat_cleaned.feather
# All_Amazon_r750k_empty_dropped_nonstrip.feather
# All_Amazon_r750k_trimmed_cat.feather
# ama_cat.jpeg
# ama_cat.png
# Amazon_Arts_Crafts_and_Sewing
# Amazon_Books
# Amazon_Clothing_Shoes_and_Jewelry
# Amazon_Electronics
# Amazon_Grocery_and_Gourmet_Food
# Amazon_Industrial_and_Scientific
# Amazon_Marketing
# Amazon_Musical_Instruments
# Amazon_Pet_Supplies
# a.png
# a.txt
# Electronics_tfidf_sgd_leaf.pkl
# graph.png
# graph.txt
# MetaDatas_Unzipped
# OutputFile.png
# Pet_Supplies.hdf5
# Smol_Amazon
# test-output
# Walmart_Marketing

# %% [markdown]
# # Import common libraries

# %%
import pandas as pd
from sklearn.base import BaseEstimator, TransformerMixin
from random import shuffle

# !pip install swifter
# !pip install sklearn-hierarchical-classification==1.3.2

import swifter
from sklearn_hierarchical_classification.classifier import HierarchicalClassifier
from sklearn_hierarchical_classification.constants import ROOT
from sklearn_hierarchical_classification.metrics import h_fbeta_score, multi_labeled
# Out:
# Requirement already satisfied: swifter in /usr/local/lib/python3.7/dist-packages (1.0.9)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from swifter) (4.1.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.0)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.7/dist-packages (from swifter) (5.8.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (7.6.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (2.12.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (4.62.3)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.1.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (21.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.19.5)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2021.11.1)
# Requirement already satisfied: toolz>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.11.2)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (4.10.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.1.3)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (1.0.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (57.4.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.8.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (2.6.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.9.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2018.9)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (0.2.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (5.3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.12.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (22.3.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bleach>=3.1.1->swifter) (3.0.6)
# Requirement already satisfied: sklearn-hierarchical-classification==1.3.2 in /usr/local/lib/python3.7/dist-packages (1.3.2)
# Requirement already satisfied: numpy>=1.13.1 in /usr/local/lib/python3.7/dist-packages (from sklearn-hierarchical-classification==1.3.2) (1.19.5)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.7/dist-packages (from sklearn-hierarchical-classification==1.3.2) (2.6.3)
# Requirement already satisfied: scikit-learn>=0.19.0 in /usr/local/lib/python3.7/dist-packages (from sklearn-hierarchical-classification==1.3.2) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from sklearn-hierarchical-classification==1.3.2) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.0->sklearn-hierarchical-classification==1.3.2) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.0->sklearn-hierarchical-classification==1.3.2) (3.0.0)

# %% [markdown]
# # Notebook settings

# %%
### Dataset configuration
# The parquet folder. It should be located inside datasets/.
DATASET_NAME   = 'Electronics.parquet'
# The input text column
DEPTH = 2 
FEATURE_COLS = ['title']
### Checkpoint configuration
# Whether to train from scratch or to load a checkpoint
TRAIN_FROM_SCRATCH=True
# Checkpoint iteration to load if not training from scratch
LOAD_ITERATION=0
# Last or best results from that iteration?
LOAD_BEST=True

### System configuration
# Will try to use your NVIDIA GPU if one is available. Set to False to force CPU computation
PREFER_GPU         = True
# If you don't have the huggingface transformers library installed, flip this to True.
# You only need to do this once. Once DistilBERT has been downloaded, it will be cached in your system's default user cache folder.
# Once it is cached, please set this to False to avoid redownloads.
INSTALL_DISTILBERT = False

# %% [markdown]
# # Import data
# Here we'll finally be using the randomly-sampled 750k-row subset.

# %%
data = dd.read_parquet('../../datasets/{}'.format(DATASET_NAME))
with pd.option_context('display.max_colwidth', None):
    print (data.iloc[0])
# Out:
# category                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [Camera & Photo, Video Surveillance, Surveillance Systems, Surveillance DVR Kits]
# title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Genuine Geovision 1 Channel 3rd Party NVR IP Software with USB Dongle Onvif PSIA
# description    The following camera brands and models have been tested for compatibility with GV-Software.\nGeoVision \tACTi \tArecont Vision \tAXIS \tBosch \tCanon\nCNB \tD-Link \tEtroVision \tHikVision \tHUNT \tIQEye\nJVC \tLG \tMOBOTIX \tPanasonic \tPelco \tSamsung\nSanyo \tSony \tUDP \tVerint \tVIVOTEK \t \n \nCompatible Standard and Protocol\nGV-System also allows for integration with all other IP video devices compatible with ONVIF(V2.0), PSIA (V1.1) standards, or RTSP protocol.\nONVIF \tPSIA \tRTSP \t  \t  \t \nNote: Specifications are subject to change without notice. Every effort has been made to ensure that the information on this Web site is accurate. No liability is assumed for incidental or consequential damages arising from the use of the information or products contained herein.
# brand                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      GeoVision
# feature                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [Genuine Geovision 1 Channel NVR IP Software, Support 3rd Party IP Camera, USB Dongle]
# Name: 0, dtype: object

# %%
# Just keep title and description for now
data = data[['title', 'description', 'category']]

# %% [markdown]
# # Build full category tree
# Normally this would be passed in, but since we don't have one, we'll have to generate.
#
# We'll both generate an AnyTree (for visualisation) and a hierarchy for `sklearn-hierarchical-classifiation`.

# %% [markdown]
# ## Import anytree stuff

# %%
# !apt install libgraphviz-dev
# !pip install graphviz
# !python -m pip install anytree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgraphviz-dev is already the newest version (2.40.1-2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (0.10.1)
# Requirement already satisfied: anytree in /usr/local/lib/python3.7/dist-packages (2.8.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from anytree) (1.15.0)

# %%
from anytree import Node, RenderTree
from anytree.dotexport import RenderTreeGraph
from anytree.exporter import DotExporter, UniqueDotExporter
from IPython.display import Image
from functools import reduce
import cv2
from google.colab.patches import cv2_imshow
#Guide: https://github.com/c0fec0de/anytree

def make_forest(classes,depth=None):
  ama_cat = Node("Root") #Root
  for cat_list in classes:
    root = ama_cat #Reset root each time we finish an item
    for cat in cat_list[0:depth]:
      if cat != root.name:
        if not (root.children):
          root = Node(cat, parent = root)
        else:
          for child in root.children:
            found = False
            if cat in child.name:
              root = child
              found = True
              break
          if not found: 
            root = Node(cat, parent = root)
  return ama_cat

# sklearn-hierarchical-classification hierarchy format
# Since list searches are slow, we'll build a dictionary of sets as an intermediate format, 
# then convert over.
def make_hierarchy(classes, depth=None, verbose=False):
  temp = { ROOT: set()}
  for i in range(0, len(classes)):
    path = classes[i]
    if len(path) != 0:
      if verbose: print(path)
      limit = min(depth, len(path))
      if path[0] not in temp[ROOT]:
        temp[ROOT].add(path[0])
      for i in range(0, limit - 1):
        if path[i] not in temp:
          temp[path[i]] = set()
      # add leaf into one of the generated sub-dicts.
      try:
        temp[path[limit-2]].add(path[limit-1])
      except:
        pass

  hierarchy = {}
  for key in temp.keys():
    hierarchy[key] = list(temp[key])

  return hierarchy

# %%
classes = data['category']
classes.iloc[0]
# Out:
# array(['Camera & Photo', 'Video Surveillance', 'Surveillance Systems',
#        'Surveillance DVR Kits'], dtype=object)

# %%
print(RenderTree(make_forest(classes, DEPTH))) #demo forest
# Out:
# Node('/Root')
# ├── Node('/Root/Camera & Photo')
# │   ├── Node('/Root/Camera & Photo/Video Surveillance')
# │   ├── Node('/Root/Camera & Photo/Accessories')
# │   ├── Node('/Root/Camera & Photo/Binoculars & Scopes')
# │   ├── Node('/Root/Camera & Photo/Bags & Cases')
# │   ├── Node('/Root/Camera & Photo/Lighting & Studio')
# │   ├── Node('/Root/Camera & Photo/Film Photography')
# │   ├── Node('/Root/Camera & Photo/Digital Cameras')
# │   ├── Node('/Root/Camera & Photo/Tripods & Monopods')
# │   ├── Node('/Root/Camera & Photo/Lenses')
# │   ├── Node('/Root/Camera & Photo/Flashes')
# │   ├── Node('/Root/Camera & Photo/Projectors')
# │   ├── Node('/Root/Camera & Photo/Underwater Photography')
# │   ├── Node('/Root/Camera & Photo/Printers & Scanners')
# │   ├── Node('/Root/Camera & Photo/Camera Cases')
# │   ├── Node('/Root/Camera & Photo/Batteries & Chargers')
# │   └── Node('/Root/Camera & Photo/Surveillance Cameras')
# ├── Node('/Root/eBook Readers & Accessories')
# │   ├── Node('/Root/eBook Readers & Accessories/eBook Readers')
# │   ├── Node('/Root/eBook Readers & Accessories/Power Adapters')
# │   ├── Node('/Root/eBook Readers & Accessories/Covers')
# │   ├── Node('/Root/eBook Readers & Accessories/Bundles')
# │   ├── Node('/Root/eBook Readers & Accessories/Screen Protectors')
# │   ├── Node('/Root/eBook Readers & Accessories/Power Cables')
# │   ├── Node('/Root/eBook Readers & Accessories/Stands')
# │   ├── Node('/Root/eBook Readers & Accessories/Skins')
# │   ├── Node('/Root/eBook Readers & Accessories/Reading Lights')
# │   ├── Node('/Root/eBook Readers & Accessories/Sleeves')
# │   └── Node('/Root/eBook Readers & Accessories/Surveillance Camera Lenses')
# ├── Node('/Root/Computers & Accessories')
# │   ├── Node('/Root/Computers & Accessories/Computer Accessories & Peripherals')
# │   ├── Node('/Root/Computers & Accessories/Tablet Accessories')
# │   ├── Node('/Root/Computers & Accessories/Computers & Tablets')
# │   ├── Node('/Root/Computers & Accessories/Computer Components')
# │   ├── Node('/Root/Computers & Accessories/Networking Products')
# │   ├── Node('/Root/Computers & Accessories/Laptop Accessories')
# │   ├── Node('/Root/Computers & Accessories/Data Storage')
# │   ├── Node('/Root/Computers & Accessories/Monitors')
# │   ├── Node('/Root/Computers & Accessories/Servers')
# │   ├── Node('/Root/Computers & Accessories/Warranties & Services')
# │   ├── Node('/Root/Computers & Accessories/Tablet Replacement Parts')
# │   ├── Node('/Root/Computers & Accessories/Screen Protectors')
# │   ├── Node('/Root/Computers & Accessories/Bags, Cases & Sleeves')
# │   ├── Node('/Root/Computers & Accessories/Chargers & Adapters')
# │   ├── Node('/Root/Computers & Accessories/Block Blue Light')
# │   ├── Node('/Root/Computers & Accessories/Styluses')
# │   ├── Node('/Root/Computers & Accessories/USB Flash Drives')
# │   └── Node('/Root/Computers & Accessories/Internal Components')
# ├── Node('/Root/Accessories & Supplies')
# │   ├── Node('/Root/Accessories & Supplies/Audio & Video Accessories')
# │   ├── Node('/Root/Accessories & Supplies/Batteries, Chargers & Accessories')
# │   ├── Node('/Root/Accessories & Supplies/Telephone Accessories')
# │   ├── Node('/Root/Accessories & Supplies/Office Electronics Accessories')
# │   ├── Node('/Root/Accessories & Supplies/Blank Media')
# │   ├── Node('/Root/Accessories & Supplies/Cord Management')
# │   ├── Node('/Root/Accessories & Supplies/Mounts')
# │   ├── Node('/Root/Accessories & Supplies/Power Strips & Surge Protectors')
# │   ├── Node('/Root/Accessories & Supplies/Cables')
# │   └── Node('/Root/Accessories & Supplies/DVD-RW Discs')
# ├── Node('/Root/GPS, Finders & Accessories')
# │   ├── Node('/Root/GPS, Finders & Accessories/GPS System Accessories')
# │   ├── Node('/Root/GPS, Finders & Accessories/Vehicle GPS')
# │   ├── Node('/Root/GPS, Finders & Accessories/Sports & Handheld GPS')
# │   ├── Node('/Root/GPS, Finders & Accessories/GPS Trackers')
# │   └── Node('/Root/GPS, Finders & Accessories/Item Finders')
# ├── Node('/Root/Headphones')
# │   ├── Node('/Root/Headphones/Earbud Headphones')
# │   ├── Node('/Root/Headphones/Over-Ear Headphones')
# │   ├── Node('/Root/Headphones/On-Ear Headphones')
# │   ├── Node('/Root/Headphones/Fleece')
# │   └── Node('/Root/Headphones/Block Blue Light')
# ├── Node('/Root/Car & Vehicle Electronics')
# │   ├── Node('/Root/Car & Vehicle Electronics/Marine Electronics')
# │   ├── Node('/Root/Car & Vehicle Electronics/Aviation Electronics')
# │   ├── Node('/Root/Car & Vehicle Electronics/Vehicle Electronics Accessories')
# │   ├── Node('/Root/Car & Vehicle Electronics/Car Electronics')
# │   ├── Node('/Root/Car & Vehicle Electronics/Fish Finders & Depth Finders')
# │   └── Node('/Root/Car & Vehicle Electronics/Amplifiers')
# ├── Node('/Root/Television & Video')
# │   ├── Node('/Root/Television & Video/Satellite Television')
# │   ├── Node('/Root/Television & Video/Projection Screens')
# │   ├── Node('/Root/Television & Video/Streaming Media Players')
# │   ├── Node('/Root/Television & Video/DVD Players & Recorders')
# │   ├── Node('/Root/Television & Video/Televisions')
# │   ├── Node('/Root/Television & Video/Home Theater Systems')
# │   ├── Node('/Root/Television & Video/AV Receivers & Amplifiers')
# │   ├── Node('/Root/Television & Video/TV-DVD Combos')
# │   ├── Node('/Root/Television & Video/DVD-VCR Combos')
# │   ├── Node('/Root/Television & Video/Blu-ray Players & Recorders')
# │   ├── Node('/Root/Television & Video/Analog-to-Digital (DTV) Converters')
# │   ├── Node('/Root/Television & Video/HD DVD Players')
# │   ├── Node('/Root/Television & Video/Video Glasses')
# │   ├── Node('/Root/Television & Video/Television Accessories')
# │   └── Node('/Root/Television & Video/LED & LCD TVs')
# ├── Node('/Root/Home Audio')
# │   ├── Node('/Root/Home Audio/Speakers')
# │   ├── Node('/Root/Home Audio/Home Theater')
# │   ├── Node('/Root/Home Audio/Wireless & Streaming Audio')
# │   ├── Node('/Root/Home Audio/Compact Radios & Stereos')
# │   ├── Node('/Root/Home Audio/Stereo System Components')
# │   ├── Node('/Root/Home Audio/Turntables & Accessories')
# │   ├── Node('/Root/Home Audio/Home Audio Accessories')
# │   └── Node('/Root/Home Audio/Surround Sound Systems')
# ├── Node('/Root/Portable Audio & Video')
# │   ├── Node('/Root/Portable Audio & Video/Portable Speakers & Docks')
# │   ├── Node('/Root/Portable Audio & Video/Cases')
# │   ├── Node('/Root/Portable Audio & Video/Portable CD Players')
# │   ├── Node('/Root/Portable Audio & Video/Chargers & Power Adapters')
# │   ├── Node('/Root/Portable Audio & Video/Microcassette Recorders')
# │   ├── Node('/Root/Portable Audio & Video/Cassette Player Adapters')
# │   ├── Node('/Root/Portable Audio & Video/Radios')
# │   ├── Node('/Root/Portable Audio & Video/Portable & Handheld TVs')
# │   ├── Node('/Root/Portable Audio & Video/Cassette Players & Recorders')
# │   ├── Node('/Root/Portable Audio & Video/CB & Two-Way Radios')
# │   ├── Node('/Root/Portable Audio & Video/Boomboxes')
# │   ├── Node('/Root/Portable Audio & Video/Minidisc Players')
# │   ├── Node('/Root/Portable Audio & Video/Portable DVD Players')
# │   ├── Node('/Root/Portable Audio & Video/Digital Voice Recorders')
# │   ├── Node('/Root/Portable Audio & Video/Bluetooth & FM Transmitters')
# │   ├── Node('/Root/Portable Audio & Video/Remote Controls')
# │   ├── Node('/Root/Portable Audio & Video/Armbands')
# │   ├── Node('/Root/Portable Audio & Video/Batteries & Battery Packs')
# │   ├── Node('/Root/Portable Audio & Video/Screen Protectors')
# │   ├── Node('/Root/Portable Audio & Video/Cables')
# │   └── Node('/Root/Portable Audio & Video/Skins & Decals')
# ├── Node('/Root/Security & Surveillance')
# │   ├── Node('/Root/Security & Surveillance/Security Sensors')
# │   ├── Node('/Root/Security & Surveillance/Radio Scanners')
# │   ├── Node('/Root/Security & Surveillance/Accessories')
# │   ├── Node('/Root/Security & Surveillance/Home Security Systems')
# │   ├── Node('/Root/Security & Surveillance/Horns & Sirens')
# │   ├── Node('/Root/Security & Surveillance/Biometrics')
# │   ├── Node('/Root/Security & Surveillance/Surveillance Video Equipment')
# │   ├── Node('/Root/Security & Surveillance/Motion Detectors')
# │   └── Node('/Root/Security & Surveillance/Barking-Dog Alarms')
# ├── Node('/Root/Wearable Technology')
# │   ├── Node('/Root/Wearable Technology/Accessories')
# │   ├── Node('/Root/Wearable Technology/Clips, Arm & Wristbands')
# │   ├── Node('/Root/Wearable Technology/Smartwatches')
# │   ├── Node('/Root/Wearable Technology/Virtual Reality')
# │   ├── Node('/Root/Wearable Technology/Glasses')
# │   └── Node('/Root/Wearable Technology/Rings')
# └── Node('/Root/Service Plans')
#     └── Node('/Root/Service Plans/Electronics')

# %%
classifier_hierarchy = make_hierarchy(classes, DEPTH)
classifier_hierarchy
# Out:
# {'<ROOT>': ['Accessories & Supplies',
#   'Computers & Accessories',
#   'Headphones',
#   'eBook Readers & Accessories',
#   'Television & Video',
#   'Home Audio',
#   'Portable Audio & Video',
#   'Wearable Technology',
#   'Accessories',
#   'Car & Vehicle Electronics',
#   'Camera & Photo',
#   'GPS, Finders & Accessories',
#   'Security & Surveillance',
#   'Service Plans'],
#  'Accessories': ['Surveillance Camera Lenses'],
#  'Accessories & Supplies': ['Audio & Video Accessories',
#   'Mounts',
#   'Cord Management',
#   'Telephone Accessories',
#   'Blank Media',
#   'Cables',
#   'DVD-RW Discs',
#   'Batteries, Chargers & Accessories',
#   'Office Electronics Accessories',
#   'Power Strips & Surge Protectors'],
#  'Camera & Photo': ['Lenses',
#   'Lighting & Studio',
#   'Printers & Scanners',
#   'Video',
#   'Tripods & Monopods',
#   'Film Photography',
#   'Surveillance Cameras',
#   'Video Surveillance',
#   'Digital Cameras',
#   'Accessories',
#   'Flashes',
#   'Binoculars & Scopes',
#   'Underwater Photography',
#   'Camera Cases',
#   'Batteries & Chargers',
#   'Projectors',
#   'Bags & Cases'],
#  'Car & Vehicle Electronics': ['Fish Finders & Depth Finders',
#   'Car Electronics',
#   'Amplifiers',
#   'Marine Electronics',
#   'Aviation Electronics',
#   'Vehicle Electronics Accessories'],
#  'Computers & Accessories': ['Computer Accessories & Peripherals',
#   'Chargers & Adapters',
#   'Laptop Accessories',
#   'Networking Products',
#   'Bags, Cases & Sleeves',
#   'Computers & Tablets',
#   'Servers',
#   'Screen Protectors',
#   'Tablet Accessories',
#   'Block Blue Light',
#   'Styluses',
#   'Internal Components',
#   'Computer Components',
#   'Warranties & Services',
#   'Data Storage',
#   'Monitors',
#   'Tablet Replacement Parts',
#   'USB Flash Drives'],
#  'GPS, Finders & Accessories': ['GPS System Accessories',
#   'Vehicle GPS',
#   'Item Finders',
#   'GPS Trackers',
#   'Sports & Handheld GPS'],
#  'Headphones': ['Earbud Headphones',
#   'Fleece',
#   'Over-Ear Headphones',
#   'Block Blue Light',
#   'On-Ear Headphones'],
#  'Home Audio': ['Turntables & Accessories',
#   'Home Theater',
#   'Stereo System Components',
#   'Surround Sound Systems',
#   'Speakers',
#   'Compact Radios & Stereos',
#   'Home Audio Accessories',
#   'Wireless & Streaming Audio'],
#  'Portable Audio & Video': ['Cassette Players & Recorders',
#   'Chargers & Power Adapters',
#   'Portable Speakers & Docks',
#   'Bluetooth & FM Transmitters',
#   'Remote Controls',
#   'Cassette Player Adapters',
#   'Cables',
#   'Microcassette Recorders',
#   'Screen Protectors',
#   'Batteries & Battery Packs',
#   'Digital Voice Recorders',
#   'Portable & Handheld TVs',
#   'Skins & Decals',
#   'Portable CD Players',
#   'Portable DVD Players',
#   'Minidisc Players',
#   'Armbands',
#   'Boomboxes',
#   'CB & Two-Way Radios',
#   'Radios',
#   'Cases'],
#  'Security & Surveillance': ['Home Security Systems',
#   'Surveillance Video Equipment',
#   'Security Sensors',
#   'Biometrics',
#   'Accessories',
#   'Horns & Sirens',
#   'Barking-Dog Alarms',
#   'Radio Scanners',
#   'Motion Detectors'],
#  'Service Plans': ['Electronics'],
#  'Television & Video': ['Streaming Media Players',
#   'TV-DVD Combos',
#   'HD DVD Players',
#   'Projection Screens',
#   'LED & LCD TVs',
#   'Video Glasses',
#   'AV Receivers & Amplifiers',
#   'Satellite Television',
#   'Televisions',
#   'Blu-ray Players & Recorders',
#   'DVD-VCR Combos',
#   'Home Theater Systems',
#   'Analog-to-Digital (DTV) Converters',
#   'DVD Players & Recorders',
#   'Television Accessories'],
#  'Wearable Technology': ['Smartwatches',
#   'Rings',
#   'Accessories',
#   'Glasses',
#   'Clips, Arm & Wristbands',
#   'Virtual Reality'],
#  'eBook Readers & Accessories': ['Skins',
#   'Stands',
#   'Power Cables',
#   'Sleeves',
#   'Reading Lights',
#   'Screen Protectors',
#   'Covers',
#   'Power Adapters',
#   'Bundles',
#   'eBook Readers']}

# %% [markdown]
# # Train-test data preparation
# ## Splitting

# %%
FULL_SET = True
TRAIN_SET_RATIO = 0.8
VAL_SET_RATIO = 0.1
# The rest is test set
# Don't change this if you want a consistent sampling for easier comparisons
RANDOM_SEED = 123
small_data = None

if not FULL_SET:
    small_data = data.sample(frac = 0.25, random_state=RANDOM_SEED)

train_set = None
test_set = None
if FULL_SET:
    train_set = data.sample(frac = TRAIN_SET_RATIO, random_state=RANDOM_SEED)
    val_test_set = data.drop(train_set.index)
else:
    train_set = small_data.sample(frac = TRAIN_SET_RATIO, random_state=RANDOM_SEED)
    val_test_set = small_data.drop(train_set.index)

val_set = val_test_set.sample(frac = VAL_SET_RATIO / (1-TRAIN_SET_RATIO), random_state=RANDOM_SEED)
test_set = val_test_set.drop(val_set.index)

train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

print(train_set.shape)
print(val_set.shape)
print(test_set.shape)
# Out:
# (481622, 3)
# (60203, 3)
# (60202, 3)

# %% [markdown]
# ## Separating X and y

# %%
# For now, only train against title and description
X_train = train_set[FEATURE_COLS]
X_test = test_set[FEATURE_COLS]
y_train = train_set['category'].swifter.apply(lambda row: row[min(DEPTH - 1, len(row) - 1)])
y_test = test_set['category'].swifter.apply(lambda row: row[min(DEPTH - 1, len(row) - 1)])

# Check dimensionalities
print(X_train.values.shape)
print(y_train.values.shape)
# Out:
# Pandas Apply:   0%|          | 0/481622 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/60202 [00:00<?, ?it/s]
# (481622, 1)
# (481622,)

# %% [markdown]
# # Build pipeline
# ## Helper classes and libraries

# %%
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from tempfile import mkdtemp
cachedir = mkdtemp()

class ColumnSelector(BaseEstimator, TransformerMixin):
  def __init__(self, key, verbose=False):
    self.key = key
    self.verbose = verbose

  def fit(self, x, y=None):
    return self

  def transform(self, df):
    if self.verbose:
      print('Selecting column',self.key)
    return df[self.key]

import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize

# These can't be put inside the class since they don't have _unload(), which prevents
# joblib from correctly parallelising the class if included.
stemmer = SnowballStemmer('english')
stop_words = set(stopwords.words('english'))

class ColumnStemmer(BaseEstimator, TransformerMixin):
  def __init__(self, verbose=False):
    self.verbose = verbose

  def stem_and_concat(self, text):
    words = word_tokenize(text)
    result_list = map(lambda word: stemmer.stem(word) if word not in stop_words else word, words)
    return ' '.join(result_list)

  def fit(self, x, y=None):
    return self

  def transform(self, series):
    if self.verbose:
      print('Stemming column', series.name)
    return series.swifter.apply(self.stem_and_concat)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Base classifier
# For use at every node. Currently an SVM with a linear kernel.

# %%
from sklearn import svm, linear_model
import joblib
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
import time

bclf = make_pipeline(linear_model.SGDClassifier(
    loss='modified_huber', # Good perf in papers
    class_weight='balanced', # To fix our gross category example count imbalance
))

# %% [markdown]
# ## Hierarchical pipeline
# Takes the base classifier and construct a tree of classifiers.

# %%
clf = HierarchicalClassifier(
  base_estimator=bclf,
  class_hierarchy=classifier_hierarchy,
)

# %% [markdown]
# ## Main pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer
from tempfile import mkdtemp
cachedir = mkdtemp()

def get_main_pipeline(clf):
  return Pipeline([
    ('selector', ColumnSelector(key='title', verbose=True)),
    ('stemmer', ColumnStemmer(verbose=True)),
    ('tfidf', TfidfVectorizer(min_df=50)),

    # Use a SVC classifier on the combined features
    ('clf', clf),
  ])

# %% [markdown]
# ## Training time

# %%
folder_name = 'checkpoints-' + DATASET_NAME
# !mkdir $folder_name
PICKLE_PATH = './{}/current.pkl'.format(folder_name)


if (TRAIN_FROM_SCRATCH):
  clf_sgd = get_main_pipeline(clf)

  start=time.time()
  clf_sgd.fit(X_train, y_train)

  end=time.time()
  print('Hierarchy took', end - start, 'ms')
  joblib.dump(clf_sgd, PICKLE_PATH)
else:
  clf_sgd = joblib.load(PICKLE_PATH)
# Out:
# Selecting column title
# Stemming column title
# Pandas Apply:   0%|          | 0/481622 [00:00<?, ?it/s]
# Hierarchy took 514.923938035965 ms

# %% [markdown]
# # Test run

# %%
prediction = clf_sgd.predict(test_set.head(30))
result = pd.DataFrame(data={'name': test_set.head(30)['title'], 'desc': test_set.head(30).description, 'actual': y_test.head(30), 'predicted': prediction})
result
# Out:
# Selecting column title
# Stemming column title
# Pandas Apply:   0%|          | 0/30 [00:00<?, ?it/s]
#                                                  name  ...                           predicted
# 0                                      One Hot Summer  ...                    Security Sensors
# 1   Kelby Training DVD: Adobe Photoshop CS5 Crash ...  ...             DVD Players & Recorders
# 2                                       Natural Order  ...                  Laptop Accessories
# 3   The Runes of the Earth : The Last Chronicles o...  ...                       eBook Readers
# 4   Nook Hd + 9-Inch Groovy Protective Stand Cover...  ...                              Covers
# 5                             Nook Vara Stylus 2-in-1  ...                              Covers
# 6   NOOK HD+ Protective Cover Fits 9 inch NOOK HD+...  ...                              Covers
# 7   Barnes & Noble Jonathan Adler Book Reader Cove...  ...                              Covers
# 8                     Shmirshky: think inside the box  ...                        Bags & Cases
# 9            Passing the Nevada Math Proficiency Exam  ...                       eBook Readers
# 10                                     Comes the Dark  ...                       eBook Readers
# 11                                Not a Sparrow Falls  ...                  Laptop Accessories
# 12           A Small Percentage (Small Percentage, 1)  ...                        Bags & Cases
# 13       Critical and Creative Thinking for Teenagers  ...                        Bags & Cases
# 14                   Seven Blessings of the Atonement  ...                       eBook Readers
# 15  Ignite: Artful Coloring Book for Adults Signed...  ...                   Lighting & Studio
# 16  Slim Acer iconia A1-830 Tablet Standard LED Wa...  ...                  Tablet Accessories
# 17  Slim Kurio 10s Tablet Standard LED Wall Home C...  ...                  Tablet Accessories
# 18  Amazon Kindle Fire HD 7 POWERED (OTG) Micro-US...  ...  Computer Accessories & Peripherals
# 19  LG Motion 4G POWERED (OTG) Micro-USB to USB 2....  ...  Computer Accessories & Peripherals
# 20  Motorola DROiD RAZR (OTG) Micro-USB to USB 2.0...  ...  Computer Accessories & Peripherals
# 21  Acer iconia W4 POWERED (OTG) Micro-USB to USB ...  ...  Computer Accessories & Peripherals
# 22  Amazon Kindle Fire HD (2013) POWERED (OTG) Mic...  ...  Computer Accessories & Peripherals
# 23  OnePlus One POWERED (OTG) Micro-USB to USB 2.0...  ...  Computer Accessories & Peripherals
# 24  LG G3 mini POWERED (OTG) Micro-USB to USB 2.0 ...  ...  Computer Accessories & Peripherals
# 25  Premium AT&T Avail 2 SmartPhone Stylus Custom ...  ...                  Tablet Accessories
# 26  Essential 64GB Samsung Galaxy S2 Mini Micro SD...  ...  Computer Accessories & Peripherals
# 27  PREMIUM USB Adapter Power Kit for Amazon Kindl...  ...                  Tablet Accessories
# 28  Samsung SM-T800 MHL/Micro-USB to HDMI High Spe...  ...           Audio & Video Accessories
# 29  Essential 64GB LG G3 Micro SDHC Card is custom...  ...  Computer Accessories & Peripherals
#
# [30 rows x 4 columns]

# %% [markdown]
# # Evaluation

# %%
# from sklearn import metrics

# test_output = clf_sgd.predict(X_test)

# print("Accuracy:", metrics.accuracy_score(y_test, test_output))
# # Model Precision: what percentage of positive tuples are labeled as such?
# print("Precision:", metrics.precision_score(y_test, test_output, average='weighted'))

# %%
from sklearn import metrics
from sklearn import preprocessing
y_avg = preprocessing.label_binarize(y_test,classes = clf_sgd.classes_)
score = clf_sgd.predict_proba(X_test)

test_output = clf_sgd.predict(X_test)

print("Accuracy:", metrics.accuracy_score(y_test, test_output))
# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:", metrics.precision_score(y_test, test_output, average='weighted'))
print("Average Precision Score: ", metrics.average_precision_score(y_avg,score,average = "micro"))
# Out:
# Selecting column title
# Stemming column title
# Pandas Apply:   0%|          | 0/60202 [00:00<?, ?it/s]
# Selecting column title
# Stemming column title
# Pandas Apply:   0%|          | 0/60202 [00:00<?, ?it/s]
# Accuracy: 0.7380485698149564
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Precision: 0.7067970687643473
# Average Precision Score:  0.41491435142837707
